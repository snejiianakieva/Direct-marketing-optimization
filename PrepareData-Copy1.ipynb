# %%
import pandas as pd
from pandas import read_excel

file_name = 'mf_revenue_prediction.xlsx' 
mf_revenue_prediction = read_excel(file_name)

file_name = 'cc_revenue_prediction.xlsx' 
cc_revenue_prediction = read_excel(file_name)

file_name = 'cl_revenue_prediction.xlsx' 
cl_revenue_prediction = read_excel(file_name)

data = mf_revenue_prediction[:40].merge(cc_revenue_prediction[:40], how="outer", on="Client")
data = data.merge(cl_revenue_prediction[:40], how="outer", on="Client")
data = data.fillna(0)
revenues =  data[["mf_revenue_prediction", "cc_revenue_prediction", "cl_revenue_prediction"]].max(axis=1)
print(revenues)
data.to_excel("checkrevenues.xlsx", index=False)
data["revenues"]=revenues
print(data)
data.to_excel("check.xlsx", index=False)
final_offer = data.sort_values("revenues", ascending=False)
final_offer = final_offer[["Client", "mf_revenue_prediction", "cc_revenue_prediction", "cl_revenue_prediction"]]
print(final_offer)
final_offer.to_excel("final_offer.xlsx", index=False)
# Out:
# 0      14.954437
# 1      11.458863
# 2      11.215317
# 3       3.592315
# 4       3.568817
#          ...
# 105    11.056110
# 106    11.044712
# 107    11.035544
# 108    11.016601
# 109    11.015413
# Length: 110, dtype: float64
#      Client  mf_revenue_prediction  cc_revenue_prediction  \
# 0       643               4.290136                    0.0
# 1      1329               4.144451                    0.0
# 2       143               3.665828                    0.0
# 3      1496               3.592315                    0.0
# 4      1408               3.568817                    0.0
# ..      ...                    ...                    ...
# 105    1569               0.000000                    0.0
# 106    1025               0.000000                    0.0
# 107    1493               0.000000                    0.0
# 108     846               0.000000                    0.0
# 109     123               0.000000                    0.0
#
#      cl_revenue_prediction   revenues
# 0                14.954437  14.954437
# 1                11.458863  11.458863
# 2                11.215317  11.215317
# 3                 0.000000   3.592315
# 4                 0.000000   3.568817
# ..                     ...        ...
# 105              11.056110  11.056110
# 106              11.044712  11.044712
# 107              11.035544  11.035544
# 108              11.016601  11.016601
# 109              11.015413  11.015413
#
# [110 rows x 5 columns]
#     Client  mf_revenue_prediction  cc_revenue_prediction  \
# 0      643               4.290136               0.000000
# 80    1041               0.000000               0.000000
# 82     775               0.000000               0.000000
# 81     678               0.000000               0.000000
# 68     886               0.000000               4.519551
# ..     ...                    ...                    ...
# 35     604               3.146828               0.000000
# 36    1055               3.142854               0.000000
# 37     510               3.131818               0.000000
# 38     732               3.130650               0.000000
# 39    1135               3.130326               0.000000
#
#     cl_revenue_prediction
# 0               14.954437
# 80              14.933940
# 82              14.108321
# 81              14.108321
# 68              13.520399
# ..                    ...
# 35               0.000000
# 36               0.000000
# 37               0.000000
# 38               0.000000
# 39               0.000000
#
# [110 rows x 4 columns]
