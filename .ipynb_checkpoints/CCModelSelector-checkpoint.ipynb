# %%
import pandas as pd
from pandas import read_excel

file_name = 'training_data.xlsx' 
training_data = read_excel(file_name)
training_data = training_data.fillna(0)
# Out:
# /home/syanakieva/anaconda3/lib/python3.7/site-packages/pandas/compat/_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)
#      Client  Sex  Age  Tenure  Count_CA  Count_SA  Count_MF  Count_OVD  \
# 0         1  1.0   51       7         1       0.0       0.0        1.0
# 1         2  0.0   43     152         1       1.0       0.0        0.0
# 2         6  1.0   24      19         1       0.0       0.0        0.0
# 3         8  1.0   64      30         1       0.0       0.0        1.0
# 4        13  1.0   66     132         1       1.0       0.0        0.0
# ..      ...  ...  ...     ...       ...       ...       ...        ...
# 964    1607  0.0   38      21         1       0.0       0.0        0.0
# 965    1608  1.0   63     108         1       0.0       0.0        0.0
# 966    1612  0.0   63     114         1       0.0       0.0        1.0
# 967    1613  0.0   46      45         1       0.0       0.0        0.0
# 968    1615  0.0    7     180         2       1.0       0.0        1.0
#
#      Count_CC  Count_CL  ...  TransactionsDebCash_Card  \
# 0         0.0       0.0  ...                       3.0
# 1         0.0       0.0  ...                       2.0
# 2         0.0       1.0  ...                       1.0
# 3         0.0       0.0  ...                      10.0
# 4         0.0       1.0  ...                       6.0
# ..        ...       ...  ...                       ...
# 964       0.0       1.0  ...                       0.0
# 965       1.0       1.0  ...                       2.0
# 966       0.0       1.0  ...                       2.0
# 967       0.0       0.0  ...                       2.0
# 968       0.0       0.0  ...                       1.0
#
#      TransactionsDebCashless_Card  TransactionsDeb_PaymentOrder  Sale_MF  \
# 0                            12.0                           9.0        1
# 1                             2.0                           1.0        0
# 2                             0.0                           0.0        0
# 3                             1.0                           0.0        0
# 4                            17.0                          10.0        0
# ..                            ...                           ...      ...
# 964                           0.0                           0.0        0
# 965                          10.0                           4.0        0
# 966                           0.0                           2.0        0
# 967                          12.0                           8.0        1
# 968                           1.0                          13.0        0
#
#      Sale_CC  Sale_CL  Revenue_MF  Revenue_CC  Revenue_CL  _merge
# 0          0        0   26.972679         0.0         0.0    both
# 1          0        0    0.000000         0.0         0.0    both
# 2          0        0    0.000000         0.0         0.0    both
# 3          0        0    0.000000         0.0         0.0    both
# 4          0        0    0.000000         0.0         0.0    both
# ..       ...      ...         ...         ...         ...     ...
# 964        0        0    0.000000         0.0         0.0    both
# 965        0        0    0.000000         0.0         0.0    both
# 966        0        0    0.000000         0.0         0.0    both
# 967        0        0    2.088571         0.0         0.0    both
# 968        0        0    0.000000         0.0         0.0    both
#
# [969 rows x 37 columns]

# %%
feature_cols = list(training_data.columns[1:-6])
target_cols = list(training_data.columns[-5:-4])

X_all = training_data[feature_cols]
Y_all = training_data[target_cols]
print(Y_all)
# Out:
#      Sale_CC
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 964        0
# 965        0
# 966        0
# 967        0
# 968        0
#
# [969 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
3
X_train, X_test, Y_train, Y_test = train_test_split(X_all, Y_all, test_size=0.4, random_state=42)
print(X_train.shape[0])
print(X_test.shape[0])
# Out:
# 581
# 388

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, Y_train)

Y_predict = model.predict(X_test)

accuracy_score = accuracy_score(Y_test, Y_predict)
print(accuracy_score)
# Out:
# 0.6675257731958762

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import pickle

model = RandomForestClassifier()
model.fit(X_train, Y_train)

Y_predict = model.predict(X_test)

accuracy_score = accuracy_score(Y_test, Y_predict)
print(accuracy_score)
filename = "ccmodel.pkl"
pickle.dump(model, open(filename, "wb"))
# Out:
# 0.7654639175257731
# /home/syanakieva/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

model = KNeighborsClassifier()
model.fit(X_train, Y_train)

Y_predict = model.predict(X_test)

accuracy_score = accuracy_score(Y_test, Y_predict)
print(accuracy_score)
# Out:
# 0.7190721649484536
# /home/syanakieva/anaconda3/lib/python3.7/site-packages/sklearn/neighbors/_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

model = MLPClassifier()
model.fit(X_train, Y_train)

Y_predict = model.predict(X_test)

accuracy_score = accuracy_score(Y_test, Y_predict)
print(accuracy_score)
# Out:
# /home/syanakieva/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 0.6262886597938144

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

model = SVC()
model.fit(X_train, Y_train)

Y_predict = model.predict(X_test)

accuracy_score = accuracy_score(Y_test, Y_predict)
print(accuracy_score)
# Out:
# 0.7551546391752577
# /home/syanakieva/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
model = RandomForestClassifier()
model.fit(X_all, Y_all)

filename = "ccmodel.pkl"
pickle.dump(model, open(filename, "wb"))
# Out:
# /home/syanakieva/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().

# %%
from matplotlib import pyplot
importance = model.feature_importances_
import numpy as np

sorted_idx = model.feature_importances_.argsort()
pyplot.figure(figsize=((15), (10)))
pyplot.barh(np.array(feature_cols)[sorted_idx], model.feature_importances_[sorted_idx], height=0.5)
pyplot.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %%
import shap
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X_all)

shap.summary_plot(shap_values[1], X_all)
