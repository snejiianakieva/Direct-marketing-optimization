# %%
import pandas as pd
from pandas import read_excel

file_name = 'cc_sales_prediction.xlsx' 
target_data = read_excel(file_name)
target_data = target_data.fillna(0)

# %%
feature_cols = list(target_data.columns[1:-2])

X_all = target_data[feature_cols]
print(X_all)
# Out:
#      Sex  Age  Tenure  Count_CA  Count_SA  Count_MF  Count_OVD  Count_CC  \
# 0      1   33      61         1         1         0          0         0
# 1      0   41      11         1         0         0          1         0
# 2      1   43     111         1         3         7          0         0
# 3      1    1      92         1         1         0          0         0
# 4      0   57      33         1         1         2          0         0
# ..   ...  ...     ...       ...       ...       ...        ...       ...
# 237    0   24     151         1         0         1          0         1
# 238    0   67      77         1         0         0          0         0
# 239    1   49     150         1         0         0          1         0
# 240    1   51     116         1         1         0          0         0
# 241    1   63      47         1         0         0          0         0
#
#      Count_CL     ActBal_CA  ...    VolumeDeb  VolumeDeb_CA  \
# 0           0   2014.426786  ...   329.285714    329.285714
# 1           0  33573.151786  ...   247.500000    247.500000
# 2           0     14.855000  ...   225.071429    225.071429
# 3           0   2175.270000  ...   919.821429    919.821429
# 4           0      7.576786  ...   470.528571    470.528571
# ..        ...           ...  ...          ...           ...
# 237         1      0.000000  ...  1680.815357   1461.696786
# 238         0     58.583929  ...     0.000000      0.000000
# 239         0    102.757143  ...   468.147143    433.405000
# 240         0    376.891071  ...   941.607143    941.607143
# 241         0   1023.336429  ...   564.767500    564.767500
#
#      VolumeDebCash_Card  VolumeDebCashless_Card  VolumeDeb_PaymentOrder  \
# 0              0.000000                0.000000              329.071429
# 1              0.000000                0.000000              247.500000
# 2              0.000000                0.000000              224.392857
# 3              0.000000                0.000000                0.000000
# 4             85.714286              221.528571              163.285714
# ..                  ...                     ...                     ...
# 237           57.142857              136.563929              931.290357
# 238            0.000000                0.000000                0.000000
# 239          275.000000              113.010714                0.000000
# 240            0.000000               28.617857              909.596429
# 241          225.000000              338.517500                0.000000
#
#      TransactionsDeb  TransactionsDeb_CA  TransactionsDebCash_Card  \
# 0                  4                   4                         0
# 1                  5                   5                         0
# 2                  4                   4                         0
# 3                  2                   2                         0
# 4                 17                  17                         2
# ..               ...                 ...                       ...
# 237               58                  21                         3
# 238                0                   0                         0
# 239               16                  13                         4
# 240               11                  11                         0
# 241               34                  34                         6
#
#      TransactionsDebCashless_Card  TransactionsDeb_PaymentOrder
# 0                               0                             3
# 1                               0                             5
# 2                               0                             3
# 3                               0                             0
# 4                               9                             6
# ..                            ...                           ...
# 237                            27                             8
# 238                             0                             0
# 239                             5                             0
# 240                             4                             6
# 241                            27                             0
#
# [242 rows x 29 columns]

# %%
from sklearn.svm import SVR
import pickle

clmodel = pickle.load(open('ccRegressionmodel.pkl', 'rb'))

prediction = clmodel.predict(X_all)
result = target_data.copy()
result["cc_revenue_prediction"] = prediction
result=result[["Client", "probability" ,"cc_revenue_prediction"]]
print(result.shape[0])
print(result[:1000])
result.to_excel("cc_revenue_prediction.xlsx", index=False)
# Out:
# 242
#      Client  probability  cc_revenue_prediction
# 0       529         0.93               4.482576
# 1       478         0.93               4.400068
# 2        83         0.92               5.150000
# 3       322         0.92               4.094715
# 4       938         0.92               5.000517
# ..      ...          ...                    ...
# 237    1399         0.61               4.374302
# 238     741         0.61               4.494059
# 239     395         0.60               4.459148
# 240     412         0.57               4.352335
# 241     546         0.56               4.437643
#
# [242 rows x 3 columns]

# %%
result
# Out:
#      Client  probability  cc_revenue_prediction
# 0       529         0.93               4.482576
# 1       478         0.93               4.400068
# 2        83         0.92               5.150000
# 3       322         0.92               4.094715
# 4       938         0.92               5.000517
# ..      ...          ...                    ...
# 237    1399         0.61               4.374302
# 238     741         0.61               4.494059
# 239     395         0.60               4.459148
# 240     412         0.57               4.352335
# 241     546         0.56               4.437643
#
# [242 rows x 3 columns]
